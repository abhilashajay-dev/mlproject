# %%
# !pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Obtaining dependency information for simpletransformers from https://files.pythonhosted.org/packages/16/c8/20d7eede93e320c0746c01d2205bdbeb388c236247244b9428e743a96de9/simpletransformers-0.64.3-py3-none-any.whl.metadata
#   Downloading simpletransformers-0.64.3-py3-none-any.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.3 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.3 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 42.3/42.3 kB 411.3 kB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (1.24.3)
# Requirement already satisfied: requests in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (2.31.0)
# Requirement already satisfied: tqdm>=4.47.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (4.65.0)
# Requirement already satisfied: regex in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (2023.6.3)
# Requirement already satisfied: transformers>=4.31.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (4.31.0)
# Collecting datasets (from simpletransformers)
#   Obtaining dependency information for datasets from https://files.pythonhosted.org/packages/66/f8/38298237d18d4b6a8ee5dfe390e97bed5adb8e01ec6f9680c0ddf3066728/datasets-2.14.4-py3-none-any.whl.metadata
#   Downloading datasets-2.14.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: scipy in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (1.11.1)
# Requirement already satisfied: scikit-learn in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (1.3.0)
# Collecting seqeval (from simpletransformers)
#   Using cached seqeval-1.2.2-py3-none-any.whl
# Requirement already satisfied: tensorboard in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (2.13.0)
# Requirement already satisfied: pandas in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (2.0.3)
# Requirement already satisfied: tokenizers in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from simpletransformers) (0.13.3)
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Obtaining dependency information for wandb>=0.10.32 from https://files.pythonhosted.org/packages/ed/d7/8927aef63869d5d379adb63dc97f9cbc53830fdf85457b84a156fabcb231/wandb-0.15.8-py3-none-any.whl.metadata
#   Downloading wandb-0.15.8-py3-none-any.whl.metadata (8.3 kB)
# Collecting streamlit (from simpletransformers)
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/20/fb/c52ddcedbb0cb142ab6f22b6d1ccee6162ade7d61ca139bc064168262ced/streamlit-1.25.0-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.25.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting sentencepiece (from simpletransformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-win_amd64.whl (977 kB)
#      ---------------------------------------- 0.0/977.5 kB ? eta -:--:--
#      ------- ------------------------------ 204.8/977.5 kB 6.3 MB/s eta 0:00:01
#      --------------------------- ---------- 706.6/977.5 kB 7.4 MB/s eta 0:00:01
#      -------------------------------------  972.8/977.5 kB 7.7 MB/s eta 0:00:01
#      -------------------------------------- 977.5/977.5 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tqdm>=4.47.0->simpletransformers) (0.4.6)
# Requirement already satisfied: filelock in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from transformers>=4.31.0->simpletransformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from transformers>=4.31.0->simpletransformers) (0.16.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from transformers>=4.31.0->simpletransformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from transformers>=4.31.0->simpletransformers) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from transformers>=4.31.0->simpletransformers) (0.3.2)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb>=0.10.32->simpletransformers) (8.1.6)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Obtaining dependency information for GitPython!=3.1.29,>=1.0.0 from https://files.pythonhosted.org/packages/67/50/742c2fb60989b76ccf7302c7b1d9e26505d7054c24f08cc7ec187faaaea7/GitPython-3.1.32-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.32-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb>=0.10.32->simpletransformers) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Obtaining dependency information for sentry-sdk>=1.0.0 from https://files.pythonhosted.org/packages/86/bb/ecb87fd214d5bbade07edf2ecdd829cf346e5b552689d6228112c6517286/sentry_sdk-1.29.2-py2.py3-none-any.whl.metadata
#   Downloading sentry_sdk-1.29.2-py2.py3-none-any.whl.metadata (8.8 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb>=0.10.32->simpletransformers)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Downloading setproctitle-1.3.2-cp310-cp310-win_amd64.whl (11 kB)
# Requirement already satisfied: setuptools in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb>=0.10.32->simpletransformers) (68.0.0)
# Collecting appdirs>=1.4.3 (from wandb>=0.10.32->simpletransformers)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb>=0.10.32->simpletransformers) (4.24.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests->simpletransformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests->simpletransformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests->simpletransformers) (2023.7.22)
# Collecting pyarrow>=8.0.0 (from datasets->simpletransformers)
#   Obtaining dependency information for pyarrow>=8.0.0 from https://files.pythonhosted.org/packages/13/68/1bc83fe2de87e2b785c503ef28293b56a4405d632f2b443cf00265b12d90/pyarrow-12.0.1-cp310-cp310-win_amd64.whl.metadata
#   Downloading pyarrow-12.0.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->simpletransformers)
#   Obtaining dependency information for dill<0.3.8,>=0.3.0 from https://files.pythonhosted.org/packages/f5/3a/74a29b11cf2cdfcd6ba89c0cecd70b37cd1ba7b77978ce611eb7a146a832/dill-0.3.7-py3-none-any.whl.metadata
#   Downloading dill-0.3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting xxhash (from datasets->simpletransformers)
#   Obtaining dependency information for xxhash from https://files.pythonhosted.org/packages/4b/7e/ab636507e53955770a2622b550265f8ee9e68feb2374ba151570a5d82e64/xxhash-3.3.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading xxhash-3.3.0-cp310-cp310-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->simpletransformers)
#   Obtaining dependency information for multiprocess from https://files.pythonhosted.org/packages/35/a8/36d8d7b3e46b377800d8dec47891cdf05842d1a2366909ae4a0c89fbc5e6/multiprocess-0.70.15-py310-none-any.whl.metadata
#   Downloading multiprocess-0.70.15-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from datasets->simpletransformers) (2023.6.0)
# Collecting aiohttp (from datasets->simpletransformers)
#   Obtaining dependency information for aiohttp from https://files.pythonhosted.org/packages/67/35/84691e1f705b1ec4ec583e27c04e0e9672dffadb86fbbd98bc3d8942f6c2/aiohttp-3.8.5-cp310-cp310-win_amd64.whl.metadata
#   Downloading aiohttp-3.8.5-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from pandas->simpletransformers) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from pandas->simpletransformers) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from scikit-learn->simpletransformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from scikit-learn->simpletransformers) (3.2.0)
# Collecting altair<6,>=4.0 (from streamlit->simpletransformers)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/b2/20/5c3b89d6f8d9938325a9330793438389e0dc94c34d921f6da35ec62095f3/altair-5.0.1-py3-none-any.whl.metadata
#   Downloading altair-5.0.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit->simpletransformers)
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from streamlit->simpletransformers) (5.3.1)
# Collecting importlib-metadata<7,>=1.4 (from streamlit->simpletransformers)
#   Obtaining dependency information for importlib-metadata<7,>=1.4 from https://files.pythonhosted.org/packages/cc/37/db7ba97e676af155f5fcb1a35466f446eadc9104e25b83366e8088c9c926/importlib_metadata-6.8.0-py3-none-any.whl.metadata
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting pillow<10,>=7.1.0 (from streamlit->simpletransformers)
#   Using cached Pillow-9.5.0-cp310-cp310-win_amd64.whl (2.5 MB)
# Collecting pympler<2,>=0.9 (from streamlit->simpletransformers)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ---------------------------------------- 0.0/164.8 kB ? eta -:--:--
#      -------------------------------------- 164.8/164.8 kB 5.0 MB/s eta 0:00:00
# Collecting rich<14,>=10.14.0 (from streamlit->simpletransformers)
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/8d/5f/21a93b2ec205f4b79853ff6e838e3c99064d5dbe85ec6b05967506f14af0/rich-13.5.2-py3-none-any.whl.metadata
#   Downloading rich-13.5.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from streamlit->simpletransformers) (8.2.2)
# Collecting toml<2,>=0.10.1 (from streamlit->simpletransformers)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from streamlit->simpletransformers) (4.5.0)
# Collecting tzlocal<5,>=1.1 (from streamlit->simpletransformers)
#   Obtaining dependency information for tzlocal<5,>=1.1 from https://files.pythonhosted.org/packages/55/a6/a75af44665e5e77e52f6789eef4f8bc056c8e039d96c804b975806942580/tzlocal-4.3.1-py3-none-any.whl.metadata
#   Downloading tzlocal-4.3.1-py3-none-any.whl.metadata (14 kB)
# Collecting validators<1,>=0.2 (from streamlit->simpletransformers)
#   Obtaining dependency information for validators<1,>=0.2 from https://files.pythonhosted.org/packages/8d/e7/c2d0758c58dbd463b4a0a650f8cf3af5c4cbb6fbc61a36ce077964286feb/validators-0.21.2-py3-none-any.whl.metadata
#   Downloading validators-0.21.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting pydeck<1,>=0.8 (from streamlit->simpletransformers)
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#      -- ------------------------------------- 0.2/4.7 MB 7.6 MB/s eta 0:00:01
#      ---- ----------------------------------- 0.5/4.7 MB 6.4 MB/s eta 0:00:01
#      ------ --------------------------------- 0.8/4.7 MB 6.4 MB/s eta 0:00:01
#      --------- ------------------------------ 1.1/4.7 MB 6.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.4/4.7 MB 6.2 MB/s eta 0:00:01
#      -------------- ------------------------- 1.7/4.7 MB 6.4 MB/s eta 0:00:01
#      ----------------- ---------------------- 2.0/4.7 MB 6.4 MB/s eta 0:00:01
#      ------------------- -------------------- 2.3/4.7 MB 6.4 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.6/4.7 MB 6.5 MB/s eta 0:00:01
#      ------------------------ --------------- 2.9/4.7 MB 6.4 MB/s eta 0:00:01
#      --------------------------- ------------ 3.2/4.7 MB 6.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.5/4.7 MB 6.3 MB/s eta 0:00:01
#      ------------------------------- -------- 3.7/4.7 MB 6.2 MB/s eta 0:00:01
#      --------------------------------- ------ 4.0/4.7 MB 6.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 4.2/4.7 MB 6.1 MB/s eta 0:00:01
#      -------------------------------------- - 4.5/4.7 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------  4.7/4.7 MB 6.1 MB/s eta 0:00:01
#      ---------------------------------------- 4.7/4.7 MB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from streamlit->simpletransformers) (6.3.2)
# Collecting watchdog>=2.1.5 (from streamlit->simpletransformers)
#   Downloading watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
#      ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#      ---------------------------------------- 82.0/82.0 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (1.57.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from tensorboard->simpletransformers) (0.38.4)
# Requirement already satisfied: jinja2 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.19.0)
# Collecting toolz (from altair<6,>=4.0->streamlit->simpletransformers)
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: six>=1.4.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets->simpletransformers)
#   Using cached multidict-6.0.4-cp310-cp310-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->datasets->simpletransformers)
#   Obtaining dependency information for async-timeout<5.0,>=4.0.0a3 from https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl.metadata
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets->simpletransformers)
#   Downloading yarl-1.9.2-cp310-cp310-win_amd64.whl (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets->simpletransformers)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/ad/1a/0035d6dd5e51580c060f80ac6819f0ea55da2b1f2dad8ad15f5d3e50d91c/frozenlist-1.4.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading frozenlist-1.4.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets->simpletransformers)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Collecting zipp>=0.5 (from importlib-metadata<7,>=1.4->streamlit->simpletransformers)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/8c/08/d3006317aefe25ea79d3b76c9650afabaf6d63d1c8443b236e7405447503/zipp-3.16.2-py3-none-any.whl.metadata
#   Downloading zipp-3.16.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit->simpletransformers)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.16.1)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit->simpletransformers)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.9.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.2.2)
# Downloading simpletransformers-0.64.3-py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.8 kB ? eta -:--:--
#    ---------------------------------------- 250.8/250.8 kB 5.1 MB/s eta 0:00:00
# Downloading wandb-0.15.8-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.1 MB 5.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.1 MB 6.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.1 MB 6.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.1 MB 6.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.7 MB/s eta 0:00:00
# Downloading datasets-2.14.4-py3-none-any.whl (519 kB)
#    ---------------------------------------- 0.0/519.3 kB ? eta -:--:--
#    ------------------------------ --------- 399.4/519.3 kB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 519.3/519.3 kB 8.2 MB/s eta 0:00:00
# Downloading streamlit-1.25.0-py2.py3-none-any.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB 8.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.7/8.1 MB 8.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/8.1 MB 8.0 MB/s eta 0:00:01
#    ------ --------------------------------- 1.4/8.1 MB 8.1 MB/s eta 0:00:01
#    -------- ------------------------------- 1.8/8.1 MB 8.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.2/8.1 MB 8.2 MB/s eta 0:00:01
#    ------------ --------------------------- 2.6/8.1 MB 8.2 MB/s eta 0:00:01
#    -------------- ------------------------- 3.0/8.1 MB 8.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 8.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.8/8.1 MB 8.5 MB/s eta 0:00:01
#    --------------------- ------------------ 4.3/8.1 MB 8.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.6/8.1 MB 8.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.6/8.1 MB 8.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.6/8.1 MB 8.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 8.9 MB/s eta 0:00:01
#    -------------------------------- ------- 6.5/8.1 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.1 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.1 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.8 MB/s eta 0:00:00
# Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#    ---------------------------------------- 0.0/471.5 kB ? eta -:--:--
#    ---------------------------------------  471.0/471.5 kB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 471.5/471.5 kB 7.3 MB/s eta 0:00:00
# Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#    ---------------------------------------- 0.0/115.3 kB ? eta -:--:--
#    ---------------------------------------- 115.3/115.3 kB ? eta 0:00:00
# Downloading aiohttp-3.8.5-cp310-cp310-win_amd64.whl (323 kB)
#    ---------------------------------------- 0.0/323.1 kB ? eta -:--:--
#    ---------------------------------------- 323.1/323.1 kB 6.8 MB/s eta 0:00:00
# Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#    ---------------------------------------- 0.0/188.5 kB ? eta -:--:--
#    --------------------------------------- 188.5/188.5 kB 11.1 MB/s eta 0:00:00
# Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Downloading pyarrow-12.0.1-cp310-cp310-win_amd64.whl (21.5 MB)
#    ---------------------------------------- 0.0/21.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/21.5 MB 14.2 MB/s eta 0:00:02
#    - -------------------------------------- 1.0/21.5 MB 12.2 MB/s eta 0:00:02
#    -- ------------------------------------- 1.5/21.5 MB 12.0 MB/s eta 0:00:02
#    --- ------------------------------------ 2.0/21.5 MB 11.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 2.6/21.5 MB 11.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.1/21.5 MB 11.8 MB/s eta 0:00:02
#    ------ --------------------------------- 3.4/21.5 MB 11.9 MB/s eta 0:00:02
#    ------- -------------------------------- 4.3/21.5 MB 11.9 MB/s eta 0:00:02
#    --------- ------------------------------ 4.9/21.5 MB 12.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 5.5/21.5 MB 12.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 6.1/21.5 MB 12.1 MB/s eta 0:00:02
#    ------------ --------------------------- 6.7/21.5 MB 12.2 MB/s eta 0:00:02
#    ------------- -------------------------- 7.3/21.5 MB 12.3 MB/s eta 0:00:02
#    -------------- ------------------------- 7.9/21.5 MB 12.4 MB/s eta 0:00:02
#    --------------- ------------------------ 8.6/21.5 MB 12.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 9.2/21.5 MB 12.5 MB/s eta 0:00:01
#    ------------------ --------------------- 9.8/21.5 MB 12.6 MB/s eta 0:00:01
#    ------------------- -------------------- 10.4/21.5 MB 12.6 MB/s eta 0:00:01
#    -------------------- ------------------- 11.1/21.5 MB 12.8 MB/s eta 0:00:01
#    --------------------- ------------------ 11.8/21.5 MB 13.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 12.5/21.5 MB 13.1 MB/s eta 0:00:01
#    ------------------------ --------------- 13.1/21.5 MB 13.4 MB/s eta 0:00:01
#    ------------------------- -------------- 13.8/21.5 MB 14.2 MB/s eta 0:00:01
#    -------------------------- ------------- 14.4/21.5 MB 13.6 MB/s eta 0:00:01
#    --------------------------- ------------ 15.0/21.5 MB 13.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 15.6/21.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------ --------- 16.3/21.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------ --------- 16.4/21.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------ --------- 16.4/21.5 MB 13.6 MB/s eta 0:00:01
#    --------------------------------- ------ 18.1/21.5 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 18.7/21.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------ --- 19.4/21.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- -- 20.0/21.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- -- 20.2/21.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- -- 20.2/21.5 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------  21.3/21.5 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  21.3/21.5 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  21.3/21.5 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  21.3/21.5 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  21.3/21.5 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  21.5/21.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 21.5/21.5 MB 6.7 MB/s eta 0:00:00
# Downloading rich-13.5.2-py3-none-any.whl (239 kB)
#    ---------------------------------------- 0.0/239.7 kB ? eta -:--:--
#    ---------------------------------------  235.5/239.7 kB ? eta -:--:--
#    ---------------------------------------  235.5/239.7 kB ? eta -:--:--
#    ---------------------------------------- 239.7/239.7 kB 1.6 MB/s eta 0:00:00
# Downloading sentry_sdk-1.29.2-py2.py3-none-any.whl (215 kB)
#    ---------------------------------------- 0.0/215.6 kB ? eta -:--:--
#    ---------------------------------------- 215.6/215.6 kB ? eta 0:00:00
# Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Downloading validators-0.21.2-py3-none-any.whl (25 kB)
# Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#    ---------------------------------------- 0.0/134.8 kB ? eta -:--:--
#    ---------------------------------------- 134.8/134.8 kB 8.3 MB/s eta 0:00:00
# Downloading xxhash-3.3.0-cp310-cp310-win_amd64.whl (29 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading frozenlist-1.4.0-cp310-cp310-win_amd64.whl (44 kB)
#    ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#    ---------------------------------------- 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB ? eta 0:00:00
# Downloading zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py): started
#   Building wheel for pathtools (setup.py): finished with status 'done'
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8801 sha256=84c10f155986ad896aaf2b0b035d2da170d5722b32225195dca6b8a7a2407293
#   Stored in directory: c:\users\abhilash\appdata\local\pip\cache\wheels\e7\f3\22\152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: sentencepiece, pathtools, appdirs, zipp, xxhash, watchdog, validators, toolz, toml, smmap, setproctitle, sentry-sdk, pytz-deprecation-shim, pympler, pyarrow, pillow, multidict, mdurl, frozenlist, docker-pycreds, dill, blinker, async-timeout, yarl, tzlocal, pydeck, multiprocess, markdown-it-py, importlib-metadata, gitdb, aiosignal, seqeval, rich, GitPython, aiohttp, wandb, altair, streamlit, datasets, simpletransformers
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 10.0.0
#     Uninstalling Pillow-10.0.0:
#       Successfully uninstalled Pillow-10.0.0
# Successfully installed GitPython-3.1.32 aiohttp-3.8.5 aiosignal-1.3.1 altair-5.0.1 appdirs-1.4.4 async-timeout-4.0.3 blinker-1.6.2 datasets-2.14.4 dill-0.3.7 docker-pycreds-0.4.0 frozenlist-1.4.0 gitdb-4.0.10 importlib-metadata-6.8.0 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.0.4 multiprocess-0.70.15 pathtools-0.1.2 pillow-9.5.0 pyarrow-12.0.1 pydeck-0.8.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.5.2 sentencepiece-0.1.99 sentry-sdk-1.29.2 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.64.3 smmap-5.0.0 streamlit-1.25.0 toml-0.10.2 toolz-0.12.0 tzlocal-4.3.1 validators-0.21.2 wandb-0.15.8 watchdog-3.0.0 xxhash-3.3.0 yarl-1.9.2 zipp-3.16.2

# %%
import pandas as pd
import json

# %%
with open (r"../data/q&a/train.json", "r") as f:
    train = json.load(f)

# %%
train
# Out:
# [{'context': 'Mistborn is a series of epic fantasy novels written by American author Brandon Sanderson.',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'Who is the author of the Mistborn series?',
#     'answers': [{'text': 'Brandon Sanderson', 'answer_start': 71}]}]},
#  {'context': 'The first series, published between 2006 and 2008, consists of The Final Empire,The Well of Ascension, and The Hero of Ages.',
#   'qas': [{'id': '00002',
#     'is_impossible': False,
#     'question': 'When was the series published?',
#     'answers': [{'text': 'between 2006 and 2008', 'answer_start': 28}]},
#    {'id': '00003',
#     'is_impossible': False,
#     'question': 'What are the three books in the series?',
#     'answers': [{'text': 'The Final Empire, The Well of Ascension, and The Hero of Ages',
#       'answer_start': 63}]},
#    {'id': '00004',
#     'is_impossible': True,
#     'question': 'Who is the main character in the series?',
#     'answers': []}]}]

# %%
with open (r"../data/q&a/test.json", "r") as f:
    test = json.load(f)
test
# Out:
# [{'context': 'The series primarily takes place in a region called the Final Empire on a world called Scadrial, where the sun and sky are red, vegetation is brown, and the ground is constantly being covered under black volcanic ashfalls.',
#   'qas': [{'id': '00001',
#     'is_impossible': False,
#     'question': 'Where does the series take place?',
#     'answers': [{'text': 'region called the Final Empire', 'answer_start': 38},
#      {'text': 'world called Scadrial', 'answer_start': 74}]}]},
#  {'context': '"Mistings" have only one of the many Allomantic powers, while "Mistborns" have all the powers.',
#   'qas': [{'id': '00002',
#     'is_impossible': False,
#     'question': 'How many powers does a Misting possess?',
#     'answers': [{'text': 'one', 'answer_start': 21}]},
#    {'id': '00003',
#     'is_impossible': True,
#     'question': 'What are Allomantic powers?',
#     'answers': []}]}]

# %%
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs
import logging

# %%
model_type ='bert'
if model_type == 'bert':
    model_name = 'bert-base-uncased'
elif model_type == 'roberta':
    model_name = 'roberta-base'
elif model_type == 'distilbert':
    model_name = 'distilbert-base-uncased'

# %%
model_name
# Out:
# 'bert-base-uncased'

# %%
# Configure the model
model_args = QuestionAnsweringArgs()
model_args.train_batch_size = 16
model_args.evaluate_during_training = True
model_args.n_best_size = 3
model_args.num_train_epochs = 2

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (0.15.8)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (8.1.6)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (3.1.32)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (1.29.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (6.0.1)
# Requirement already satisfied: pathtools in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (0.1.2)
# Requirement already satisfied: setproctitle in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (1.3.2)
# Requirement already satisfied: setuptools in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (68.0.0)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from wandb) (4.24.0)
# Requirement already satisfied: colorama in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from Click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests<3,>=2.0.0->wandb) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\abhilash\anaconda3\envs\nlp\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)

# %%
### Advanced Methodology
train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"outputs/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 5,
    "evaluate_during_training_steps": 1000,
    "wandb_project": "Question Answer Application",
    "wandb_kwargs": {"name": model_name},
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":3,
    # "use_early_stopping": True,
    # "early_stopping_metric": "mcc",
    # "n_gpu": 2,
    # "manual_seed": 4,
    # "use_multiprocessing": False,
    "train_batch_size": 128,
    "eval_batch_size": 64,
    # "config": {
    #     "output_hidden_states": True
    # }
    
}

# %%
model = QuestionAnsweringModel(model_type, model_name, args=train_args)
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\mlprojectkrish-naiks\notebook\customQ&A.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/mlprojectkrish-naiks/notebook/customQ%26A.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> model = QuestionAnsweringModel(model_type, model_name, args=train_args)
#
# File c:\Users\Abhilash\anaconda3\envs\nlp\lib\site-packages\simpletransformers\question_answering\question_answering_model.py:231, in QuestionAnsweringModel.__init__(self, model_type, model_name, args, use_cuda, cuda_device, **kwargs)
#     229             self.device = torch.device(f"cuda:{cuda_device}")
#     230     else:
# --> 231         raise ValueError(
#     232             "'use_cuda' set to True when cuda is unavailable."
#     233             " Make sure CUDA is available or set use_cuda=False."
#     234         )
#     235 else:
#     236     self.device = "cpu"
#
# ValueError: 'use_cuda' set to True when cuda is unavailable. Make sure CUDA is available or set use_cuda=False.
